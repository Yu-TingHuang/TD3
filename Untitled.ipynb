# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("./models_TwoPlayer/HalfCheetah-v2/RMSprop/action_noise_0.1/alpha_0.1/0/results.npy")
plt.plot(data)

# %%
data = np.load("./models_TwoPlayer/HalfCheetah-v2/ExtraAdam/action_noise_0.1/alpha_0.1/0/results.npy")
plt.plot(data)

# %%
data = np.load("./models_OnePlayer/HalfCheetah-v2/RMSprop/action_noise_0.1/alpha_0.0/0/results.npy")
plt.plot(data)

# %%
data = np.load("./models_OnePlayer/HalfCheetah-v2/ExtraAdam/action_noise_0.1/alpha_0.0/0/results.npy")
plt.plot(data)
